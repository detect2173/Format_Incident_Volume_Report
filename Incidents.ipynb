# %%
import pandas as pd
from pandas_datareader import data
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Current_IncVol_Cleaned.csv')
df.head(3)
# Out:
#    Unnamed: 0                 IncidentDesc           BehaviorDt   StudLname  \
# 0          22  Volunteering for extra duty  2022-07-01 14:30:00       MASSE
# 1          39  Volunteering for extra duty  2022-07-01 14:30:00       SMITH
# 2          41  Volunteering for extra duty  2022-07-01 19:00:00  TERONI III
#
#   StudFname DormName   StudId       Location IncidentType  \
# 0     KALEB  Dorm 20  1877218  Bldg.2 - Rm 4     Positive
# 1    EDWARD  Dorm 18  1885903  Bldg.2 - Rm 4     Positive
# 2    GEORGE  Dorm 21  1884619        Dorm 21     Positive
#
#                                         BehaviorComm
# 0  Kaleb and Ed brought over a large supply order...
# 1  Ed and Kaleb brought over a large order of sup...
# 2  Student assisted writer in majoring a newly em...

# %%
counts = df['IncidentDesc'].value_counts()
counts
# Out:
# Volunteering for extra duty                         34
# Student was observed modeling positive behaviors     5
# Helping other students                               3
# Student exceeded expectations                        3
# Failure to follow the student handbook rules         3
# Using profanity, abusive, or obscene language        1
# Student exhibited teamwork today                     1
# Name: IncidentDesc, dtype: int64

# %%
plt.style.use('dark_background')
counts.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='IncidentDesc'>

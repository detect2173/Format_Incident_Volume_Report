# %%
import pandas as pd
from matplotlib import *
from matplotlib.pyplot import pie, axis, show, plot, bar, legend
# %matplotlib inline

# %%
df = pd.read_csv ('Current_IncVol_Cleaned.csv')

# %%
sums = df["IncidentDesc"].value_counts().plot(kind='pie',legend=True, labels=None)
print(sums)
axis('equal')
pie(sums)
show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       1 sums = df["IncidentDesc"].value_counts().plot(kind='pie',legend=True, labels=None)
# ----> 2 print(sums.sum())
#       3 axis('equal')
#       4 pie(sums.sum())
#
# AttributeError: 'AxesSubplot' object has no attribute 'sum'
